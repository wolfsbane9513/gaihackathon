# %% [markdown]
# ## Install Libraries

# %%
# !pip install langchain==0.0.164 openai tiktoken pandas scikit-learn numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Import Libraries

# %%
import os
import pandas as pd
from langchain.llms import AzureOpenAI
from langchain.embeddings import OpenAIEmbeddings
import pandas as pd

# %% [markdown]
# ## Load OpenAI Keys

# %%
os.environ["OPENAI_API_TYPE"] = 'azure'
os.environ["OPENAI_API_VERSION"] = "2023-03-15-preview"
os.environ["OPENAI_API_BASE"] = 'https://genai-train.openai.azure.com/'
os.environ["OPENAI_API_KEY"] = 'daa31766af2c4c92980449324feb24dd'
davinci_model = 'prompt_eng_davinci'
chat_model = 'text-35-turbo'

# %% [markdown]
# ## Transcript of Insurance Conversation

# %%
transcript = """agent: Hello! Thank you for contacting our claim support. I'm sorry to hear about your accident. Are you in a safe place to talk?\\nuser:Yes I am\\agent: That's good to hear. May I have your policy number, please?\\nuser:PA-23-554668\\nagent: Thank you. Could you please provide me with your driver's license number?\\nuser: VIC525658\\nagent: Thank you for that. Can you tell me when and where the accident took place to the best of your memory?\\nuser: Last saturday arund 11 am near the Woolsworth supermarket in Queens street in CBD\\nagent: Thanks for the information. Can you please provide me with more details about the accident? How did it happen and how much damage was caused to your car?\\nuser: I was at the supermarket parking and was about to park my vehicle. I am looking at the rear view camera and suddenly another car hit me from the back. He was in a hurry to park at the same place. what an idiot. Anyway, he didn't even notice I was driving back. The place was well lit and my indicator was also on\\nagent: I'm sorry to hear that. Do you know if anyone was injured in the accident?\\nuser: I wasn't injured. The other driver might have some bruises I am not sure\\nagent: I see. Did you report the accident to the police? If yes, do you have a report number?\\nuser: Yes I did. VPD-23-01015\\nagent: Thanks for providing that. Is there anything else that you would like to mention regarding the accident or the damage to your vehicle?\\nuser: Will I have to pay the other person or am I covered?\\nagent: Under your comprehensive auto policy, you are covered for both first and third party liability. This means that if the other driver was at fault, your policy will cover the damage to their vehicle as well as any injuries sustained. If you were at fault, your policy will cover the damage to the other person's vehicle and any injuries sustained up to the limit of your policy. The specifics of your coverage will be determined by the adjuster assigned to your case, and they will be able to give you more information about the claims process. Rest assured, we will assess your claim as soon as possible and provide you with the necessary assistance. Please let me know if there is anything else you need help with.\\nuser: I am definitely not at fault...it's his fault for sure..he didn't see me\\nagent: I understand your frustration. Please be assured that our claims adjuster will thoroughly investigate the incident and determine the party responsible for the accident. Based on their findings, your claim will be assessed accordingly. We are committed to providing you with the best possible assistance throughout the claims process. If you have any further questions or concerns, please do not hesitate to ask\\nuser: how long will it take to get the damage repaired?\\nagent: The length of time it takes to repair the damage to your vehicle can vary depending on the extent of the damage, the availability of parts, and the workload of the repair shop. Our claims adjuster will be able to provide you with an estimated timeline once they have assessed the damage to your vehicle. They will also be able to recommend a reputable repair shop for you to take your vehicle to. If you have any other questions, please feel free to ask.\\nuser: please keep me posted\\nagent: Of course, we will keep you informed of any updates regarding your claim throughout the claims process. You can also contact us at any time if you have any questions or concerns. Thank you for choosing our insurance company for your auto insurance needs. We appreciate your business and we are here to help you through this difficult time."""
transcript = '\n'.join(transcript.split('\\n'))
print(transcript)
# Out:
# agent: Hello! Thank you for contacting our claim support. I'm sorry to hear about your accident. Are you in a safe place to talk?
# user:Yes I am\agent: That's good to hear. May I have your policy number, please?
# user:PA-23-554668
# agent: Thank you. Could you please provide me with your driver's license number?
# user: VIC525658
# agent: Thank you for that. Can you tell me when and where the accident took place to the best of your memory?
# user: Last saturday arund 11 am near the Woolsworth supermarket in Queens street in CBD
# agent: Thanks for the information. Can you please provide me with more details about the accident? How did it happen and how much damage was caused to your car?
# ...

# %%
 # Create langchain llm model.
 davinci_model = 'prompt_eng_davinci'
 llm = AzureOpenAI(deployment_name=davinci_model,model_name="text-davinci-003")

# %% [markdown]
# #Q1. Use text-davinci-003 llm to extract the following entities in json format:
# - Policy_Number
# - Driver_License_Number
# - Mobile_Number
# - SSN_Number
# - Injury_Updates
# - Derive_Date_of_Event(dd/mm/yyyy)_Time(HH/MM)
# - Place_of_Event
# - Police_Report_Number
# - First_Party_Injury(Y/N)
# - Third_Party_Injury(Y/N)
# - Hospitalisation_Details
# - Accident_Details
# - Fatality(Y/N)
# - Minor_Involved_In_Accident(Y/N)
# - Elderly_Involved_In_Accident(Y/N)

# %%
 #Solution 1
entity_prompt = #Replace with your prompt

# %%
# Write a prompt for entity extraction
print(llm(entity_prompt))
# Out:
# {
#     "Policy_Number": "PA-23-554668",
#     "Driver_License_Number": "VIC525658",
#     "Mobile_Number": "",
#     "SSN_Number": "",
#     "Injury_Updates": "The other driver might have some bruises I am not sure",
#     "Derive_Date_of_Event(dd/mm/yyyy)_Time(HH/MM)": "Last saturday arund 11 am",
#     "Place_of_Event": "Woolsworth supermarket in Queens street in CBD",
#     "Police_Report_Number": "VPD-23-01015",
#     "First_Party_Injury(Y/N)": "N",
#     "Third_Party_Injury(Y/N)": "Uncertain",
#     "Hospitalisation_Details": "",
#     "Accident_Details": "The other car hit me from the back while I was looking at the rear view camera",
#     "Fatality(Y/N)": "N",
#     "Minor_Involved_In_Accident(Y/N)": "N

# %% [markdown]
# # Q2. Generate the detailed summary of Transcript

# %%
summary_prompt = #Replace with your prompt

# %%
print(llm(summary_prompt))
# Out:
# {
#     "summary": "The customer contacted the claim support center regarding an accident that took place near the Woolsworth supermarket in Queens street in CBD last Saturday. The customer provided their policy number and driver's license number, and gave details about the accident. The customer was not injured but the other driver may have sustained some injuries. The customer also reported the accident to the police and provided the report number. The customer asked if they will have to pay the other person, and was told that their coverage will depend on the findings of the adjuster assigned to the case. The adjuster will also provide an estimated timeline for the repair of the damage to the customer's vehicle. The customer was assured that the company will keep them informed of any updates throughout the claims process."
# }

# %% [markdown]
# #Q3. Generate the classification

# %%
classification_prompt = #Replace with your prompt

# %%
print(llm(classification_prompt))
# Out:
# {
#   "Class": "New Request"
# }

# %% [markdown]
# #Q4. Generate auto email for the transcript with POV of Agent

# %%
#Solution
autoemail_prompt = #Replace with your prompt

# %%
print(llm(autoemail_prompt))
# Out:
# Dear [User],
#
# Thank you for contacting our claim support. I understand that you were recently involved in a car accident. I apologize for the inconvenience caused.
#
# We have taken note of all the details shared by you and will be beginning the assessment of your claim. Our claims adjuster will thoroughly investigate the incident and determine the party responsible for the accident. Based on their findings, your claim will be assessed accordingly.
#
# In order to move forward with the repair process, the adjuster will need to assess the extent of the damage done to your vehicle. Once they have done this, they will be able to provide you with an estimated timeline for the repair process. They will also be able to recommend a reputable repair shop for you to take your vehicle to.
#
# ...

# %% [markdown]
# #Q5. Generate the call sentiment and find the root-cause

# %%
#Solution 
sentiment_prompt = #Replace with your prompt

# %%
print(llm(sentiment_prompt))
# Out:
# {
#     "Sentiment": "Frustrated",
#     "Root-Cause": "The user is frustrated due to the accident, which was caused by the other driver's negligence"
# }

# %% [markdown]
# # Q6. Generate Issue wise Trouble-shooting articles using historical transcript

# %%
historical_transcripts = ["""User: Hello, I'm trying to log into my account but I can't remember my password. Can you help me reset it?
Agent: Of course! I can help you reset your password. First, please confirm your account email address so I can send you a password reset link.""",
"""User: Hi, I'm having trouble logging into my account. Can you help me reset my password?
Agent: Sure thing! To reset your password, please go to the login page and click on the 'Forgot Password' link. Follow the prompts to reset your password, and you'll be all set.""",
"""User: ""I'm having trouble logging into my account because I can't remember my password. Can you help me reset it?
Agent: ""Certainly! To reset your password, please visit the login page and click on the 'Forgot Password' link. Then enter the email address associated with your account, and we'll send you a password reset email. Just follow the instructions in the email to reset your password.""",
"""User: Hi, I've forgotten my password and I need to log into my account. Can you help me reset it?
Agent: Of course! In order to reset your password, we'll need to verify your account ownership. Can you provide your account email address, as well as the name on the account?""",
"""User: Hi, I'm having trouble logging into my account because I've forgotten my password. Can you help me reset it?
Agent: Sure thing! To reset your password, please visit the login page and click on the 'Forgot Password' link. Then enter the email address associated with your account, and we'll send you a password reset email. Just follow the instructions in the email to reset your password""",
"""User: Hello, I'm having trouble with my Outlook account. I keep getting an error message when I try to send emails.
Agent: I'm sorry to hear that. Can you tell me a little more about the error message you're seeing? That will help me troubleshoot the issue.""",
"""User: Hi, I'm having some trouble with Outlook. It's not loading properly and I can't access my emails.
Agent: Hi there, I'm sorry to hear that you're having trouble with Outlook. Can you tell me a little bit more about the issue you're experiencing?
User: Yeah, when I try to open Outlook it just hangs and doesn't load. I've tried restarting my computer but it didn't help.
Agent: Okay, it sounds like there might be an issue with the Outlook application itself. Can you try resetting the application and see if that helps? To do this, go to File > Options > Reset Settings, and then select ""Reset all settings."" This will reset the Outlook application to its default settings and may resolve the issue.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""User: Hello, I'm having some problems with Outlook. My emails are not showing up in my inbox.
Agent: Hi there, I'm sorry to hear that you're having issues with Outlook. Can you tell me a little bit more about what's happening?
User: Well, when I open Outlook I see that I have new emails, but they're not showing up in my inbox. Instead, they're showing up in the ""Junk Email"" folder.
Agent: Hmm, that's definitely not right. It sounds like your Outlook may be misbehaving. Can you try running a quick repair on the application and see if that helps? To do this, go to File > Account Settings > Account Settings, and then select the ""Repair"" button. This should resolve any issues with the Outlook application.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""User: Hey, I'm having some trouble with Outlook. It's not sending or receiving emails.
Agent: Hi there, I'm sorry to hear that you're having trouble with Outlook. Can you tell me a little bit more about the issue you're experiencing?
User: Well, I can't send or receive any emails. It just says ""connection to the server failed.""
Agent: Okay, it sounds like there might be an issue with your internet connection or your email server. Can you try resetting your internet router and see if that helps? If that doesn't work, it might be worth checking with your email service provider to see if there are any known issues or outages.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""User: Hi, I'm having some problems with Outlook. It's not loading my emails.
Agent: Hi there, I'm sorry to hear that you're having issues with Outlook. Can you tell me a little bit more about what's happening?
User: Well, when I open Outlook it's not showing any of my emails. It's just a blank screen.
Agent: Hmm, that's definitely not right. It sounds like there might be an issue with your""",
"""User: Hi, I'm having some trouble resetting my password. I can't seem to remember my old one and the reset process isn't working.
Agent: Hi there, I'm sorry to hear that you're having trouble resetting your password. Can you tell me a little bit more about the issue you're experiencing?
User: Well, I can't remember my old password and when I try to reset it, it's not working. I keep getting an error message.
Agent: Okay, it sounds like there might be an issue with the password reset process. Can you try resetting your password using a different method? For example, you can try using your recovery email or phone number to reset your password. If that doesn't work, it might be worth reaching out to your email service provider or the organization you're trying to reset your password for to see if they can assist you.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""User: Hello, I'm having some problems resetting my password. It's not accepting my new password.
Agent: Hi there, I'm sorry to hear that you're having issues resetting your password. Can you tell me a little bit more about what's happening?
User: Well, when I try to reset my password it says my new password is invalid. I'm not sure what's going on.
Agent: Okay, it sounds like there might be an issue with the password requirements. Make sure that your new password meets the requirements for the system or service you're trying to reset it for. For example, it may need to be a certain length, include a mix of upper and lowercase letters, and include at least one number or special character. If you're still having trouble, it might be worth trying a different password or reaching out to the organization you're trying to reset your password for to see if they can assist you.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""User: Hey, I'm having some trouble resetting my password. I can't remember my old one and the reset process isn't working.
Agent: Hi there, I'm sorry to hear that you're having trouble resetting your password. Can you tell me a little bit more about the issue you're experiencing?
User: Well, I can't remember my old password and when I try to reset it, it's not working. I keep getting an error message.
Agent: Okay, it sounds like there might be an issue with the password reset process. Can you try resetting your password using a different method, such as your recovery email or phone number? If that doesn't work, it might be worth reaching out to the organization you're trying to reset your password for to see if they can assist you. In the meantime, you might want to try using a password manager to help you keep track of your passwords and create secure ones.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""User: Hi, I'm having some trouble connecting to Salesforce. It's not letting me log in.
Agent: Hi there, I'm sorry to hear that you're having trouble connecting to Salesforce. Can you tell me a little bit more about the issue you're experiencing?
User: Well, I'm trying to log in to Salesforce but it's not accepting my credentials. I keep getting an error message.
Agent: Okay, it sounds like there might be an issue with your login credentials. Can you double-check that you're using the correct username and password? If you're sure they're correct, it might be worth trying to reset your password to see if that resolves the issue. If you're still having trouble, it might be worth reaching out to Salesforce customer support to see if they can assist you.
User: Okay, I'll try that. Thanks for your help.
Agent: No problem, I'm glad I could assist. Let me know if you have any further issues or if there's anything else I can do to help.""",
"""Agent: Hi there, how can I help you today?
User: Hi, I'm having some issues connecting Salesforce to my account. Every time I try to log in, I get an error message.
Agent: I see. Can you tell me a little more about the error message you're receiving?
User: It says ""Invalid login credentials."" I'm sure I'm entering the correct username and password, so I'm not sure what's going on.
Agent: It's possible that there may be an issue with your account or with the Salesforce servers. Can you try resetting your password and trying again? If that doesn't work, it might be a good idea to contact Salesforce support for further assistance.""",
"""Agent: Hello, how can I assist you with your Salesforce issue today?
User: Hi, I'm trying to connect Salesforce to my company's account, but it's not working. Every time I enter my login information, I get an error message saying ""Connection Failed.""
User: I've tried using different web browsers and clearing my cache, but nothing seems to be working.
Agent: It sounds like you may be experiencing a connectivity issue. Can you try connecting to Salesforce from a different device or network to see if that helps? If the problem persists, it might be a good idea to check with your IT team to see if there are any known issues or outages that could be causing the problem.""",
"""Agent: Hi there, how can I assist you with your Salesforce issue today?
User: Hi, I'm trying to connect Salesforce to our account, but I keep getting an error message saying ""API Limits Exceeded."" I'm not sure what to do.
Agent: It sounds like you may have reached the maximum number of API calls allowed for your account. Can you try reducing the number of API calls you're making and see if that helps? If the problem persists, it might be a good idea to reach out to Salesforce support for further assistance.""",
"""Agent: Hello, how can I help you with your Salesforce issue today?
User: Hi, I'm having trouble connecting Salesforce to our account. Every time I try to log in, I get an error message saying ""Access Denied.""
Agent: It sounds like there may be a problem with your account permissions. Can you check with your administrator to make sure that you have the correct permissions to access Salesforce? If you do have the correct permissions and are still having trouble, it might be a good idea to contact Salesforce support for further assistance.""",
]

# %%
historical_transcripts
# Out:
# ["User: Hello, I'm trying to log into my account but I can't remember my password. Can you help me reset it?\nAgent: Of course! I can help you reset your password. First, please confirm your account email address so I can send you a password reset link.",
#  "User: Hi, I'm having trouble logging into my account. Can you help me reset my password?\nAgent: Sure thing! To reset your password, please go to the login page and click on the 'Forgot Password' link. Follow the prompts to reset your password, and you'll be all set.",
#  'User: ""I\'m having trouble logging into my account because I can\'t remember my password. Can you help me reset it?\nAgent: ""Certainly! To reset your password, please visit the login page and click on the \'Forgot Password\' link. Then enter the email address associated with your account, and we\'ll send you a password reset email. Just follow the instructions in the email to reset your password.',
# ...

# %%
#Generate Langchain Embedding class object
embedding_model = 'genai_embd'
embedding = OpenAIEmbeddings(deployment=embedding_model,chunk_size=1)

# %% [markdown]
# Hint:
# - Write a logic to group similar issues' trnascript together
# - For a single issue type, write a knowledge article
